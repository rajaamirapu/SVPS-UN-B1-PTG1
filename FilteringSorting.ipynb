# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo = pd.read_csv(url,sep = '\t')

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price']=chipo['item_price'].str.replace('$','').astype(float)

# %%
chipo_filtered = chipo.drop_duplicates(['item_name', 'choice_description', 'item_price'])

# %%
chipo_one_product = chipo_filtered[chipo_filtered.quantity==1]

# %%
products_above_10 = chipo_one_product[chipo_one_product.item_price>10]

# %%
print(products_above_10['item_name'].nunique())
# Out:
# 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
sub_chipo = chipo[['item_name', 'item_price']]

# %%
item_prices = sub_chipo.drop_duplicates()

# %%
item_prices = item_prices.sort_values(by='item_price', ascending=False)

# %%
print(item_prices)
# Out:
#                          item_name  item_price
# 3598  Chips and Fresh Tomato Salsa       44.25
# 3480                 Carnitas Bowl       35.25
# 1254               Chicken Burrito       35.00
# 3601                Veggie Burrito       33.75
# 409                   Chicken Bowl       32.94
# ...                            ...         ...
# 6                    Side of Chips        1.69
# 329                  Bottled Water        1.50
# 263              Canned Soft Drink        1.25
# 28                     Canned Soda        1.09
# 34                   Bottled Water        1.09
#
# [209 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by='item_name',ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
sorted_item_price=chipo.sort_values(by='item_price',ascending=False)

# %%
print(sorted_item_price['quantity'].iloc[0])
# Out:
# 15

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo_salad=chipo[chipo.item_name=='Veggie Salad Bowl']

# %%
len(chipo_salad)
# Out:
# 18

# %% [markdown]
# ###Step 9.Frequently Ordered item

# %%
chipo['item_name'].value_counts().idxmax()
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. How many times did someone order more than one Canned Soda?

# %%
len(chipo[(chipo.item_name=='Canned Soda') & (chipo.quantity>1)])
# Out:
# 20
